# %% [markdown]
# <a href="https://www.analytiksinc.com">![ANALYTIKS_LOGO_FINAL-01.jpg](attachment:ANALYTIKS_LOGO_FINAL-01.jpg)</a>
# <p style="text-align: right;"> © 2021. Analytiks Inc. </p>

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# ## Import Libraries

# %%
#ignore warnings
import warnings
from matplotlib import pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Standard Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %matplotlib inline

# %% [markdown]
# ### Additional Libraries

# %% [markdown]
# <a href = 'https://facebook.github.io/prophet/docs/installation.html#python'>FBProphet</a>

# %%
#FBProphet
from fbprophet import Prophet

#Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# ### Helper Functions

# %%
def forecast_metrics(y_true, y_pred):
    """Calculate MAE, MSE, RMSE, and MAPE of the forecast.
    
       Args:
           y_true: actual results
           y_pred: predicted results
    """
    
    #MAE
    mae = mean_absolute_error(y_true, y_pred)
    
    #MSE
    mse = mean_squared_error(y_true, y_pred)
    
    #RMSE
    rmse = np.sqrt(mse)
    
    #MAPE
    mape = np.mean(np.abs(y_pred - y_true)/np.abs(y_true))
    
    print(("MAE: %.2f") % mae)
    print(("MSE: %.2f") % mse)
    print(("RMSE: %.2f") % rmse)
    print(("MAPE: %.2f") % (mape * 100))

# %% [markdown]
# ## Load and Explore the Dataset

# %% [markdown]
# Filename: superstore_sales_data.csv

# %%
df = pd.read_csv('../csv-file/superstore_sales_data-edited.csv', index_col=0, parse_dates=['Request Date'])

# %% [markdown]
# View the Dataset

# %%
df.head()
# Out:
#               Order ID Request Date Completion_Date Customer_ID  \
# Row_ID
# 1       CA-2017-152156   2017-08-11      11/11/2017    CG-12520
# 2       CA-2017-152156   2017-08-11      11/11/2017    CG-12520
# 3       CA-2017-138688   2017-12-06      16/06/2017    DV-13045
# 4       US-2016-108966   2016-11-10      18/10/2016    SO-20335
# 5       US-2016-108966   2016-11-10      18/10/2016    SO-20335
#
#           Customer_Name
# Row_ID
# 1           Claire Gute
# 2           Claire Gute
# 3       Darrin Van Huff
# 4        Sean O'Donnell
# 5        Sean O'Donnell

# %% [markdown]
# Check Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9800 entries, 1 to 9800
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         9800 non-null   object
#  1   Request Date     9800 non-null   datetime64[ns]
#  2   Completion_Date  9800 non-null   object
#  3   Customer_ID      9800 non-null   object
#  4   Customer_Name    9800 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 459.4+ KB

# %%
df.nunique()
# Out:
# Order ID           4922
# Request Date       1230
# Completion_Date    1326
# Customer_ID         793
# Customer_Name       793
# dtype: int64

# %% [markdown]
# Groupby 'Request Date' and get count of 'Completed_requests', convert to Series for easier manipulation

# %%
daily = df.groupby('Request Date').agg({'Order ID':['count']})

daily.columns = ['Completed_requests']

daily.head()
# Out:
#               Completed_requests
# Request Date
# 2015-01-02                     1
# 2015-01-03                    10
# 2015-01-04                     4
# 2015-01-06                    11
# 2015-01-07                     3

# %% [markdown]
# Check Start and End Date of the Series

# %%
print("Start Date: %s | End Date: %s " % (daily.index.min(),daily.index.max()))
# Out:
# Start Date: 2015-01-02 00:00:00 | End Date: 2018-12-30 00:00:00

# %%
#Plot the Data
daily.plot(kind='line', figsize = (20,10))
plt.savefig('../graph/data1.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-f50582019e60> in <module>
#       1 #Plot the Data
#       2 daily.plot(kind='line', figsize = (20,10))
# ----> 3 plt.savefig('../graph/data1.png', bbox_inches='tight')
#
# ~\miniconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     841 def savefig(*args, **kwargs):
#     842     fig = gcf()
# --> 843     res = fig.savefig(*args, **kwargs)
#     844     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     845     return res
#
# ~\miniconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\miniconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# ~\miniconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# ~\miniconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1599         pil_kwargs.setdefault("format", format)
#    1600         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1601         image.save(fname, **pil_kwargs)
#    1602
#    1603
#
# ~\miniconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2146                 fp = builtins.open(filename, "r+b")
#    2147             else:
# -> 2148                 fp = builtins.open(filename, "w+b")
#    2149
#    2150         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../graph/data1.png'

# %%
#Get Monthly Data
monthly = daily.resample('M').apply(sum)

monthly.head()
# Out:
#               Completed_requests
# Request Date
# 2015-01-31                   126
# 2015-02-28                    84
# 2015-03-31                   161
# 2015-04-30                   121
# 2015-05-31                   146

# %%
#Plot the Data
monthly.plot(kind='line', figsize = (20,10))
plt.savefig('graph/data2.png', bbox_inches='tight')

# %% [markdown]
# ## Split into Train and Test

# %%
#We'll use the last 12 months for testing, and the remaining months for training

test = monthly[monthly.index.year == 2018]

train = monthly[monthly.index.year < 2018]

# %%
train.shape, test.shape
# Out:
# ((36, 1), (12, 1))

# %%
print("Train: Start Date: %s |  End Date: %s " % (train.index.min(),train.index.max()))
print("Test: Start Date: %s |  End Date: %s " % (test.index.min(),test.index.max()))
# Out:
# Train: Start Date: 2015-01-31 00:00:00 |  End Date: 2017-12-31 00:00:00
# Test: Start Date: 2018-01-31 00:00:00 |  End Date: 2018-12-31 00:00:00

# %% [markdown]
# _____

# %% [markdown]
# ## FB Prophet

# %%
#Convert our dataframe to the format required by Prophet

train_fb = train.reset_index()
train_fb.columns = ['ds','y']

test_fb = test.reset_index()
test_fb.columns = ['ds','y']

train_fb.head()
# Out:
#           ds    y
# 0 2015-01-31  126
# 1 2015-02-28   84
# 2 2015-03-31  161
# 3 2015-04-30  121
# 4 2015-05-31  146

# %%
#Instantiate the model

model = Prophet(seasonality_mode='multiplicative')

model.fit(train_fb)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#Create DataFrame for Forecasts
future = model.make_future_dataframe(periods=12, freq='M')
future
# Out:
#            ds
# 0  2015-01-31
# 1  2015-02-28
# 2  2015-03-31
# 3  2015-04-30
# 4  2015-05-31
# 5  2015-06-30
# 6  2015-07-31
# 7  2015-08-31
# 8  2015-09-30
# 9  2015-10-31
# 10 2015-11-30
# 11 2015-12-31
# 12 2016-01-31
# 13 2016-02-29
# 14 2016-03-31
# 15 2016-04-30
# 16 2016-05-31
# 17 2016-06-30
# 18 2016-07-31
# 19 2016-08-31
# 20 2016-09-30
# 21 2016-10-31
# 22 2016-11-30
# 23 2016-12-31
# 24 2017-01-31
# 25 2017-02-28
# 26 2017-03-31
# 27 2017-04-30
# 28 2017-05-31
# 29 2017-06-30
# 30 2017-07-31
# 31 2017-08-31
# 32 2017-09-30
# 33 2017-10-31
# 34 2017-11-30
# 35 2017-12-31
# 36 2018-01-31
# 37 2018-02-28
# 38 2018-03-31
# 39 2018-04-30
# 40 2018-05-31
# 41 2018-06-30
# 42 2018-07-31
# 43 2018-08-31
# 44 2018-09-30
# 45 2018-10-31
# 46 2018-11-30
# 47 2018-12-31

# %%
#Get Forecasts
forecast = model.predict(future)

forecast.tail(n=12)
# Out:
#            ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 36 2018-01-31  210.745725  139.992073  187.512524   210.745725   210.745725
# 37 2018-02-28  212.459098  104.446568  153.176157   212.459097   212.459098
# 38 2018-03-31  214.356046  200.647179  246.616778   214.356046   214.356047
# 39 2018-04-30  216.191803  166.342089  212.732336   216.191803   216.191804
# 40 2018-05-31  218.088752  216.030537  262.019356   218.088751   218.088753
# 41 2018-06-30  219.924509  171.381261  216.540106   219.924508   219.924510
# 42 2018-07-31  221.821457  190.741688  236.425700   221.821456   221.821459
# 43 2018-08-31  223.718406  200.878569  246.781340   223.718404   223.718408
# 44 2018-09-30  225.554163  276.918733  322.760407   225.554161   225.554165
# 45 2018-10-31  227.451112  195.231877  241.249966   227.451109   227.451114
# 46 2018-11-30  229.286868  321.243584  367.444686   229.286866   229.286871
# 47 2018-12-31  231.183817  293.242945  341.923471   231.183814   231.183820
#
#     multiplicative_terms  multiplicative_terms_lower  \
# 36             -0.227699                   -0.227699
# 37             -0.390399                   -0.390399
# 38              0.041383                    0.041383
# 39             -0.117682                   -0.117682
# 40              0.097597                    0.097597
# 41             -0.118753                   -0.118753
# 42             -0.037382                   -0.037382
# 43              0.000085                    0.000085
# 44              0.335377                    0.335377
# 45             -0.036783                   -0.036783
# 46              0.497518                    0.497518
# 47              0.369869                    0.369869
#
#     multiplicative_terms_upper    yearly  yearly_lower  yearly_upper  \
# 36                   -0.227699 -0.227699     -0.227699     -0.227699
# 37                   -0.390399 -0.390399     -0.390399     -0.390399
# 38                    0.041383  0.041383      0.041383      0.041383
# 39                   -0.117682 -0.117682     -0.117682     -0.117682
# 40                    0.097597  0.097597      0.097597      0.097597
# 41                   -0.118753 -0.118753     -0.118753     -0.118753
# 42                   -0.037382 -0.037382     -0.037382     -0.037382
# 43                    0.000085  0.000085      0.000085      0.000085
# 44                    0.335377  0.335377      0.335377      0.335377
# 45                   -0.036783 -0.036783     -0.036783     -0.036783
# 46                    0.497518  0.497518      0.497518      0.497518
# 47                    0.369869  0.369869      0.369869      0.369869
#
#     additive_terms  additive_terms_lower  additive_terms_upper        yhat
# 36             0.0                   0.0                   0.0  162.759055
# 37             0.0                   0.0                   0.0  129.515313
# 38             0.0                   0.0                   0.0  223.226698
# 39             0.0                   0.0                   0.0  190.749851
# 40             0.0                   0.0                   0.0  239.373457
# 41             0.0                   0.0                   0.0  193.807830
# 42             0.0                   0.0                   0.0  213.529327
# 43             0.0                   0.0                   0.0  223.737506
# 44             0.0                   0.0                   0.0  301.199806
# 45             0.0                   0.0                   0.0  219.084708
# 46             0.0                   0.0                   0.0  343.361294
# 47             0.0                   0.0                   0.0  316.691577

# %%
#Plot the Forecast
fig1 = model.plot(forecast, figsize=(20,10))
plt.savefig('graph/forecast3.png', bbox_inches='tight')

# %%
#Plot the Components
fig2 = model.plot_components(forecast, figsize=(20,10))
plt.savefig('graph/components4.png', bbox_inches='tight')

# %%
#Join with actual results to get the metrics 
results_df = pd.merge(forecast, monthly, left_on='ds', right_index=True)
results_df = results_df[['ds','Completed_requests','yhat']]
results_df.head()
# Out:
#           ds  Completed_requests        yhat
# 0 2015-01-31                 126   99.520268
# 1 2015-02-28                  84   88.248345
# 2 2015-03-31                 161  166.157061
# 3 2015-04-30                 121  125.900000
# 4 2015-05-31                 146  160.939959

# %%
train_results = results_df[(results_df.ds.dt.year < 2018)]
test_results = results_df[(results_df.ds.dt.year == 2018)]

# %%
#Train Metrics
forecast_metrics(train_results.Completed_requests,train_results.yhat)
# Out:
# MAE: 14.30
# MSE: 332.71
# RMSE: 18.24
# MAPE: 7.87

# %%
forecast_metrics(test_results.Completed_requests,test_results.yhat)
# Out:
# MAE: 41.75
# MSE: 2604.36
# RMSE: 51.03
# MAPE: 15.77

# %%
# Plot
plt.figure(figsize=(20,10))
plt.plot(train_results.Completed_requests, label='training')
plt.plot(test_results.Completed_requests, label='actual')
plt.plot(test_results.yhat, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=18)
plt.savefig('graph/ForecastvsActuals5.png', bbox_inches='tight')
plt.show()
